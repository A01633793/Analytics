# %% [markdown]
# <a href="https://colab.research.google.com/github/A01633793/Analytics/blob/main/ActTitanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#kaggle competitions download -c titanic
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Datasets/titanic/train.csv")
df2 = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Datasets/titanic/test.csv")

df_concatenado = pd.concat([df1, df2], axis=0)
# df=df_concatenado
df=df1

df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.columns
df.isnull().sum()
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # 1. Histograma de cada feature

# %%
#1.1 passengerId
plt.hist(df['PassengerId'], bins=10,edgecolor='white')  

plt.title('Histograma "PassengerId"')
plt.xlabel('Id del pasajero')
plt.ylabel('Frecuencia')

plt.show()

# %%
#1.2
plt.hist(df['Pclass'], bins=3,edgecolor='white',color='green')  

plt.title('Histograma "Pclass"')
plt.xlabel('Clase del pasajero')
plt.ylabel('Frecuencia')

plt.show()

# %% [markdown]
# La tercera clase, también conocida como clase de "pasajeros de cubierta", era la opción más económica disponible para los viajeros. Esta clase estaba compuesta principalmente por inmigrantes, trabajadores y personas que buscaban una vida mejor en América del Norte. La tercera clase ofrecía alojamientos más básicos y menos comodidades en comparación con las clases superiores.
#
# El hecho de que la mayoría de los pasajeros estuvieran en tercera clase resalta las disparidades sociales y económicas existentes en ese período de tiempo. Además, este hallazgo también puede indicar la amplia diversidad de personas a bordo del Titanic, provenientes de diferentes orígenes y condiciones socioeconómicas.

# %%
#1.3 Histograma de sexo
hist1=plt.hist(df['Sex'], bins=2,edgecolor='white',color='yellow')  

plt.title('Histograma "Sex"')
plt.xlabel('Sexo del pasajero')
plt.ylabel('Frecuencia')

plt.show()

# %% [markdown]
# Este Histograma revela que había una marcada disparidad en cuanto a la identificación de género entre los pasajeros. Según los registros, se ha identificado a casi 600 hombres y aproximadamente 300 mujeres a bordo de la famosa embarcación antes de su trágico hundimiento.
#
#
# Este desequilibrio de género plantea diversas interrogantes y ofrece una visión más detallada de la composición de los pasajeros del Titanic. Puede sugerir la existencia de diferentes factores que contribuyeron a esta disparidad, como las normas sociales y culturales de la época, las cuales podrían haber influido en la composición demográfica de los viajeros.

# %%
#1.4 Histograma de edad
hist1=plt.hist(df['Age'], bins=10,edgecolor='white',color='orange')  

plt.title('Histograma "Age" (edad)')
plt.xlabel('Edad del pasajero')
plt.ylabel('Frecuencia')

plt.show()

# %% [markdown]
# Un fascinante hallazgo realizado en el estudio del Titanic revela que había una notable concentración de pasajeros entre las edades de 20 y 30 años.
#
#
# Dichos datos permiten especular sobre posibles razones detrás de esta concentración de personas jóvenes en el Titanic. Puede implicar que esta franja de edad representaba una proporción significativa de los pasajeros que buscaban oportunidades en América del Norte, como inmigrantes en busca de una vida mejor o jóvenes aventureros ansiosos por explorar nuevos horizontes. También es posible que esta tendencia refleje la estructura demográfica de la sociedad de la época, donde los jóvenes adultos constituían un grupo considerable.

# %%
#1.5 Histograma de # de hermanos/esposos abordo

plt.hist(df['SibSp'], bins=10,edgecolor='white',color='red')  

plt.title('Histograma de # de hermanos/esposos abordo')
plt.xlabel('# de hermanos/esposos del pasajero')
plt.ylabel('Frecuencia')

plt.show()

# %% [markdown]
# Un hallazgo  obtenido a través del histograma revela que la mayoría de los pasajeros a bordo del Titanic no tenían familiares identificados. De hecho, la cifra más alta en el histograma corresponde a la categoría de "0 hermanos/esposos del pasajero". Esto implica que la gran mayoría de los pasajeros no estaban acompañados por sus familiares directos en el momento del viaje.
#
# Este hallazgo plantea varias posibilidades y conjeturas. Es posible que muchos de los pasajeros a bordo del Titanic fueran viajeros individuales, que emprendieron el viaje sin la compañía de sus familiares más cercanos. Esto podría indicar diferentes motivaciones de viaje, como la búsqueda de nuevas oportunidades o el deseo de aventurarse en un nuevo destino sin la compañía directa de sus seres queridos.

# %%
#1.6 Histograma de # de padres/hijos abordo

plt.hist(df['Parch'], bins=10,edgecolor='white',color='pink')  

plt.title('Histograma de # de padres/hijos abordo')
plt.xlabel('# de padres/hijos abordo del pasajero')
plt.ylabel('Frecuencia')

plt.show()

# %% [markdown]
# Este histograma nos dice es que la mayoría de los pasajeros a bordo del Titanic no tenían hijos. Esta inferencia se basa en el hecho de que no se registraron o identificaron hijos en gran parte de los datos disponibles.
#
# Esta observación podría sugerir que muchos de los pasajeros eran adultos solteros, parejas sin hijos o familias que optaron por dejar a sus hijos al cuidado de familiares o instituciones mientras emprendían el viaje.

# %%
#1.7 Histograma de tarifa del pasajero

plt.hist(df['Fare'], bins=7,edgecolor='white',color='purple')  

plt.title('Histograma de tarifa del pasajero')
plt.xlabel('$ de tarifa del pasajero')
plt.ylabel('Frecuencia')

plt.show()

# %% [markdown]
# La tarifa mas comprada fue entre 0 y 100$
#
# Este descubrimiento sugiere que una gran proporción de los pasajeros optó por tarifas más asequibles al adquirir sus boletos para viajar en el Titanic. Es posible que estas tarifas bajas fueran elegidas principalmente por pasajeros de tercera clase, quienes buscaban una opción más económica para su viaje.

# %%
#1.8 Histograma de puerto de embarcación
#	C = Cherbourg, Q = Queenstown, S = Southampton
df['Embarked'] = df['Embarked'].astype(str)
plt.hist(df['Embarked'], bins=3,edgecolor='white',color='blue')  

plt.title('Histograma puerto de embarcación del pasajero')
plt.xlabel('Puerto de embarcación del pasajero')
plt.ylabel('Frecuencia')

plt.show()

# %% [markdown]
# Este hallazgo indica una concentración prominente de pasajeros que se unieron al Titanic en Southampton en comparación con otros puertos de embarque. Southampton, ubicado en el sur de Inglaterra, fue el puerto de partida principal del Titanic en su fatídico viaje inaugural.
#
# La elección de Southampton como el punto de embarque principal puede deberse a varias razones. En aquel entonces, Southampton era un puerto activo y estratégico para el comercio y la navegación, lo que facilitaba el acceso y la partida de grandes barcos como el Titanic. Además, la ciudad contaba con buenas conexiones ferroviarias con otras partes de Inglaterra, lo que permitía a los pasajeros llegar fácilmente al puerto.

# %% [markdown]
# # Separa los datos por clases

# %%
df_survived = df[df['Survived'] == 1]
df_not_survived = df[df['Survived'] == 0]

# %% [markdown]
# # Utiliza diferentes variantes de histogramas

# %%
#Seaborn PassengerId
sns.displot(df_survived['PassengerId'], bins=30, label='Survived')
sns.displot(df_not_survived['PassengerId'], bins=30, label='Not Survived')
plt.legend(loc='upper right')
plt.xlabel('PassengerId')
plt.ylabel('Count')
plt.title('Distribución por ID de Sobrevivientes vs No Sobrevivientes (Seaborn)')
plt.show()

# %%
#Stacked PassengerId
sns.histplot(
    data = df,
    x = "PassengerId",
    hue = "Survived",
    multiple = "stack",
    bins = 30
)
# Out:
# <Axes: xlabel='PassengerId', ylabel='Count'>

# %%
#Seaborn Pclass
sns.displot(df_survived['Pclass'], bins=3, label='Survived')
sns.displot(df_not_survived['Pclass'], bins=3, label='Not Survived')
plt.legend(loc='upper right')
plt.xlabel('Pclass')
plt.ylabel('Count')
plt.title('Distribución por clase de Sobrevivientes vs No Sobrevivientes (Seaborn)')
plt.show()

# %%
#Stacked Pclass
sns.histplot(
    data = df,
    x = "Pclass",
    hue = "Survived",
    multiple = "stack",
    bins = 3
)
# Out:
# <Axes: xlabel='Pclass', ylabel='Count'>

# %%
#Seaborn Age
sns.displot(df_survived['Age'], bins=100, label='Survived')
sns.displot(df_not_survived['Age'], bins=100, label='Not Survived')
plt.legend(loc='upper right')
plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Distribución por edad de Sobrevivientes vs No Sobrevivientes (Seaborn)')
plt.show()

# %%
#Stacked Age
sns.histplot(
    data = df,
    x = "Age",
    hue = "Survived",
    multiple = "stack",
    bins = 100
)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# Otro hallazgo surge al analizar los datos de supervivencia de los pasajeros del Titanic: la mayoría de los niños y bebés lograron sobrevivir, mientras que muchos jóvenes adultos perdieron la vida en el desastre. Además, se destaca que la persona más anciana registrada a bordo del barco logró sobrevivir.
#
# Este hallazgo revela patrones distintos de supervivencia basados en diferentes grupos de edad. La supervivencia de los niños y bebés sugiere que se les dio prioridad durante la evacuación y se les ofreció una protección especial. La alta tasa de supervivencia en este grupo puede ser atribuida a la política de "mujeres y niños primero" que se implementó en el momento del desastre.

# %%
#Seaborn Sexo
sns.displot(df_survived['Sex'], bins=2, label='Survived')
sns.displot(df_not_survived['Sex'], bins=2, label='Not Survived')
plt.legend(loc='upper right')
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Distribución por sexo de Sobrevivientes vs No Sobrevivientes (Seaborn)')
plt.show()

# %%
#Stacked Sex
sns.histplot(
    data = df,
    x = "Sex",
    hue = "Survived",
    multiple = "stack",
    bins = 2
)
# Out:
# <Axes: xlabel='Sex', ylabel='Count'>

# %% [markdown]
# La disparidad en las tasas de supervivencia entre hombres y mujeres a bordo del Titanic plantea varias reflexiones sobre las dinámicas sociales y culturales de la época, así como las circunstancias particulares que se desarrollaron durante el desastre.
#
# Una posible explicación de esta diferencia de supervivencia puede estar relacionada con la política de "mujeres y niños primero" que prevaleció durante el naufragio. Se esperaba que las mujeres y los niños tuvieran prioridad en el acceso a los botes salvavidas, lo que podría explicar la mayor tasa de supervivencia entre las mujeres.
#
# Esta política reflejaba las normas y valores tradicionales que asignaban un papel protector y de prioridad a las mujeres en situaciones de peligro. Además, se creía que las mujeres eran más vulnerables y necesitaban mayor protección durante una situación de emergencia.
#
# Otra posible razón podría ser la diferenciación en las oportunidades de evacuación entre hombres y mujeres. Dado que la tercera clase, donde había una mayor proporción de hombres, estaba ubicada en las secciones inferiores del barco, es posible que tuvieran mayores dificultades para acceder a los botes salvavidas y escapar.

# %%
#Seaborn SibSp
sns.displot(df_survived['SibSp'], bins=10, label='Survived')
sns.displot(df_not_survived['SibSp'], bins=10, label='Not Survived')
plt.legend(loc='upper right')
plt.xlabel('SibSp')
plt.ylabel('Count')
plt.title('Distribución por hermanos/esposos de Sobrevivientes vs No Sobrevivientes (Seaborn)')
plt.show()

# %%
#Stacked SibSp
sns.histplot(
    data = df,
    x = "SibSp",
    hue = "Survived",
    multiple = "stack",
    bins = 10
)
# Out:
# <Axes: xlabel='SibSp', ylabel='Count'>

# %%
#Seaborn Parch
sns.displot(df_survived['Parch'], bins=10, label='Survived')
sns.displot(df_not_survived['Parch'], bins=10, label='Not Survived')
plt.legend(loc='upper right')
plt.xlabel('Parch')
plt.ylabel('Count')
plt.title('Distribución por padres/hijos de Sobrevivientes vs No Sobrevivientes (Seaborn)')
plt.show()

# %%
#Stacked Parch
sns.histplot(
    data = df,
    x = "Parch",
    hue = "Survived",
    multiple = "stack",
    bins = 10
)
# Out:
# <Axes: xlabel='Parch', ylabel='Count'>

# %%
#Seaborn Tarifa
sns.displot(df_survived['Fare'], bins=30, label='Survived')
sns.displot(df_not_survived['Fare'], bins=30, label='Not Survived')
plt.legend(loc='upper right')
plt.xlabel('Fare')
plt.ylabel('Count')
plt.title('Distribución por tarifa de Sobrevivientes vs No Sobrevivientes (Seaborn)')
plt.show()

# %%
#Stacked Tarifa
sns.histplot(
    data = df,
    x = "Fare",
    hue = "Survived",
    multiple = "stack",
    bins = 30
)
# Out:
# <Axes: xlabel='Fare', ylabel='Count'>

# %%
#Seaborn Embarcación
sns.displot(df_survived['Embarked'], bins=4, label='Survived')
sns.displot(df_not_survived['Embarked'], bins=4, label='Not Survived')
plt.legend(loc='upper right')
plt.xlabel('Embarked')
plt.ylabel('Count')
plt.title('Distribución por puerto de embarcación de Sobrevivientes vs No Sobrevivientes (Seaborn)')
plt.show()

# %%
#Stacked Embarcación
sns.histplot(
    data = df,
    x = "Embarked",
    hue = "Survived",
    multiple = "stack",
    bins = 4
)
# Out:
# <Axes: xlabel='Embarked', ylabel='Count'>

# %%
sns.pairplot(
    data = df,
    hue = "Survived"
)

# %% [markdown]
# # Escribe un hallazgo por cada grafica resultante
